# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !mkdir -p SleepStageClassificationProject/dataset
# !mkdir -p SleepStageClassificationProject/notebooks
# !mkdir -p SleepStageClassificationProject/models
# !mkdir -p SleepStageClassificationProject/results
# !mkdir -p SleepStageClassificationProject/src
# !mkdir -p SleepStageClassificationProject/report
# Out:
# /content/drive/MyDrive

# %%
# !ls SleepStageClassificationProject
# Out:
# dataset  models  notebooks  report  results  src

# %%
# %cd /content/drive/MyDrive/SleepStageClassificationProject/dataset
# Out:
# /content/drive/MyDrive/SleepStageClassificationProject/dataset

# %%
# !pwd
# Out:
# /content/drive/MyDrive/SleepStageClassificationProject/dataset

# %%
# !wget -r -N -c -np https://physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/
# Out:
# --2026-07-25 17:40:45--  https://physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/
# Resolving physionet.org (physionet.org)... 18.25.8.254
# Connecting to physionet.org (physionet.org)|18.25.8.254|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/index.html’
#
# physionet.org/files     [   <=>              ]  37.31K  51.4KB/s    in 0.7s
#
# Last-modified header missing -- time-stamps turned off.
# 2026-07-25 17:40:47 (51.4 KB/s) - ‘physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/index.html’ saved [38201]
#
# Loading robots.txt; please ignore errors.
# --2026-07-25 17:40:47--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# ...

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/download_sleepEDF.ipynb" \
"/content/drive/MyDrive/SleepStageClassificationProject/notebooks/01_download_sleepEDF.ipynb"

# %%
# %cd /content/drive/MyDrive/SleepStageClassificationProject
# Out:
# /content/drive/MyDrive/SleepStageClassificationProject

# %%
# %cd /content/drive/MyDrive/SleepStageClassificationProject
# !git init
# !git branch -M main
# Out:
# /content/drive/MyDrive/SleepStageClassificationProject
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/SleepStageClassificationProject/.git/

# %%
# %%writefile .gitignore
# dataset/
# models/
# *.edf
# *.h5
# *.pkl
# *.pth
# *.npz
# .ipynb_checkpoints/
# __pycache__/
# *.pyc
# .DS_Store
# Out:
# Writing .gitignore

# %%
# !git config user.name "fenfics"
# !git config user.email "nphatsornwattanonn@gmail.com"
# Out:
# fatal: not in a git directory
# fatal: not in a git directory

# %%
# !git add .
# !git commit -m "deleted line in git command"

from getpass import getpass
my_username = "fenfics"
token = getpass("Token: ")
# !git push https://{my_username}:{token}@github.com/fenfics/sleep-stage-classification.git main
